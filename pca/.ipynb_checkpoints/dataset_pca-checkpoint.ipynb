# %%
import numpy as np
import pandas as pd

# %%
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
import os

# %% [markdown]
# ## Introduction
#
#  This dataset has nine types of attacks, namely, Fuzzers, Analysis, Backdoors, DoS, Exploits, Generic, Reconnaissance, Shellcode and Worms. The Argus, Bro-IDS tools are used and twelve algorithms are developed to generate totally 49 features with the class label. These features are described in the UNSW-NB15_features.csv file.
#
#  The majority class is normal.

# %%
data_path = Path("/work/ts518/sta571/Imbalanced_data/data/unbalanced_data_standardized.csv")

df = pd.read_csv(data_path)
display(df.head(10))
# Out:
#         dur     spkts     dpkts    sbytes    dbytes      rate  sttl  dttl  \
# 0 -0.191029 -0.104456 -0.135769 -0.049134 -0.102726 -0.576371   252   254
# 1 -0.109485 -0.046014  0.172599 -0.046410  0.188544 -0.576345    62   252
# 2  0.040699 -0.089845 -0.026933 -0.048527 -0.012133 -0.576734    62   252
# 3  0.049729 -0.060624 -0.063212 -0.047016 -0.098563 -0.576737    62   252
# 4 -0.140417 -0.075235 -0.117630 -0.047554 -0.102057 -0.576617   254   252
# 5 -0.151052 -0.075235 -0.117630 -0.047554 -0.102057 -0.576581   254   252
# 6 -0.111459 -0.075235 -0.099490 -0.047554 -0.101459 -0.576658   254   252
# 7 -0.129286 -0.075235 -0.099490 -0.047554 -0.101459 -0.576622   254   252
# 8 -0.125996 -0.075235 -0.099490 -0.047554 -0.101459 -0.576630   254   252
# 9 -0.169855 -0.075235 -0.117630 -0.047554 -0.102057 -0.576469   254   252
#
#       sload     dload  ...  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0 -0.389897 -0.273700  ...       -0.705529             0           0
# 1 -0.389928 -0.069233  ...       -0.614256             0           0
# 2 -0.389964 -0.252044  ...       -0.522983             0           0
# 3 -0.389958 -0.275821  ...       -0.522983             1           1
# 4 -0.389927 -0.275561  ...        2.854115             0           0
# 5 -0.389919 -0.275263  ...        2.854115             0           0
# 6 -0.389941 -0.275600  ...        2.854115             0           0
# 7 -0.389933 -0.275244  ...        2.854115             0           0
# 8 -0.389935 -0.275322  ...        2.854115             0           0
# 9 -0.389894 -0.274347  ...        2.854115             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  label  \
# 0                 0   -0.715714   -0.753074                0      0
# 1                 0   -0.715714   -0.288257                0      0
# 2                 0   -0.595543   -0.288257                0      0
# 3                 0   -0.595543   -0.753074                0      0
# 4                 0   -0.595543    2.779535                0      0
# 5                 0   -0.595543    2.779535                0      0
# 6                 0   -0.715714    2.779535                0      0
# 7                 0   -0.475371    2.779535                0      0
# 8                 0   -0.475371    2.779535                0      0
# 9                 0   -0.475371    2.779535                0      0
#
#    attack_cat  attack_cat_encode
# 0      Normal                  6
# 1      Normal                  6
# 2      Normal                  6
# 3      Normal                  6
# 4      Normal                  6
# 5      Normal                  6
# 6      Normal                  6
# 7      Normal                  6
# 8      Normal                  6
# 9      Normal                  6
#
# [10 rows x 42 columns]

# %%
# EDA for `attack_cat` column: counts, percent, imbalance ratio
col = 'attack_cat'
# value counts (include NaNs if any)
counts = df[col].value_counts(dropna=False)
percent = counts / len(df) * 100
import numpy as np
# build a concise result dataframe
result = pd.DataFrame({'count': counts, 'percent': percent.round(3)})
display(result)
total = len(df)
# majority and minority (ignore zero-count classes)
majority = counts.max()
minority = counts[counts>0].min() if (counts>0).any() else 0
imbalance_ratio = majority / minority if minority>0 else np.nan
majority_prop = majority / total
print(f'Total samples: {total}')
print(f'Majority class: {counts.idxmax()} ({majority} samples, {majority_prop:.4f} proportion)')
print(f'Minority class: {counts.idxmin()} ({minority} samples)')
print(f'Imbalance ratio (majority/minority): {imbalance_ratio:.2f}')
# Out:
#                 count  percent
# Normal          56000   31.938
# Generic         40000   22.813
# Exploits        33393   19.045
# Fuzzers         18184   10.371
# DoS             12264    6.994
# Reconnaissance  10491    5.983
# Analysis         2000    1.141
# Backdoor         1746    0.996
# Shellcode        1133    0.646
# Worms             130    0.074
# Total samples: 175341
# Majority class: Normal (56000 samples, 0.3194 proportion)
# Minority class: Worms (130 samples)
# Imbalance ratio (majority/minority): 430.77

# %% [markdown]
# ## Barchart

# %%
plt.figure(figsize=(15, 6))

colors = ['steelblue'] + ['tomato'] * (len(result) - 1)
bars = plt.bar(result.index, result["percent"], color=colors)

for bar, count in zip(bars, result["count"]):
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        str(count),
        ha='center', va='bottom',
        fontsize=10
    )

plt.title("Percentage of rows by class")
plt.show()

# %%
# Keep only numeric columns and the attack_cat column
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
cols_to_keep = numeric_cols + ['attack_cat']
df = df[cols_to_keep]
print(f"Kept {len(cols_to_keep)} columns: {len(numeric_cols)} numeric + attack_cat")

display(df.head())
# Out:
# Kept 42 columns: 41 numeric + attack_cat
#         dur     spkts     dpkts    sbytes    dbytes      rate  sttl  dttl  \
# 0 -0.191029 -0.104456 -0.135769 -0.049134 -0.102726 -0.576371   252   254
# 1 -0.109485 -0.046014  0.172599 -0.046410  0.188544 -0.576345    62   252
# 2  0.040699 -0.089845 -0.026933 -0.048527 -0.012133 -0.576734    62   252
# 3  0.049729 -0.060624 -0.063212 -0.047016 -0.098563 -0.576737    62   252
# 4 -0.140417 -0.075235 -0.117630 -0.047554 -0.102057 -0.576617   254   252
#
#       sload     dload  ...  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0 -0.389897 -0.273700  ...       -0.705529             0           0
# 1 -0.389928 -0.069233  ...       -0.614256             0           0
# 2 -0.389964 -0.252044  ...       -0.522983             0           0
# 3 -0.389958 -0.275821  ...       -0.522983             1           1
# 4 -0.389927 -0.275561  ...        2.854115             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  label  \
# 0                 0   -0.715714   -0.753074                0      0
# 1                 0   -0.715714   -0.288257                0      0
# 2                 0   -0.595543   -0.288257                0      0
# 3                 0   -0.595543   -0.753074                0      0
# 4                 0   -0.595543    2.779535                0      0
#
#    attack_cat_encode  attack_cat
# 0                  6      Normal
# 1                  6      Normal
# 2                  6      Normal
# 3                  6      Normal
# 4                  6      Normal
#
# [5 rows x 42 columns]

# %%
# Standardize only numeric columns with more than 20 unique values (continuous data)
# Get numeric columns only
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Filter columns with more than 20 unique values (likely continuous)
cols_to_scale = [col for col in numeric_cols if df[col].nunique() > 40]
cols_not_scaled = [col for col in numeric_cols if df[col].nunique() <= 40]

# Standardize only continuous columns
scaler = StandardScaler()
df_clean = df.copy()
df_clean[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

print(f"Standardized {len(cols_to_scale)} columns (>40 unique values)")
print(f"Not standardized {len(cols_not_scaled)} columns (<=40 unique values): {cols_not_scaled}")

# encode attack_cat with 1,2,3... on df_clean
df_clean['attack_cat_encode'] = df_clean['attack_cat'].astype('category').cat.codes

num_indices = [df_clean.columns.get_loc(col) for col in cols_to_scale]
cat_indices = [df_clean.columns.get_loc(col) for col in cols_not_scaled]
print("Categorical column indices:", ",".join(map(str, cat_indices)))
print("Continuous/Numeric columns:", ",".join(map(str, num_indices)))
display(df_clean.head())
# Out:
# Standardized 28 columns (>40 unique values)
# Not standardized 13 columns (<=40 unique values): ['sttl', 'dttl', 'swin', 'dwin', 'trans_depth', 'ct_state_ttl', 'ct_dst_sport_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'is_sm_ips_ports', 'label', 'attack_cat_encode']
# Categorical column indices: 6,7,16,19,25,28,31,33,34,35,38,39,40
# Continuous/Numeric columns: 0,1,2,3,4,5,8,9,10,11,12,13,14,15,17,18,20,21,22,23,24,26,27,29,30,32,36,37
#         dur     spkts     dpkts    sbytes    dbytes      rate  sttl  dttl  \
# 0 -0.191029 -0.104456 -0.135769 -0.049134 -0.102726 -0.576371   252   254
# 1 -0.109485 -0.046014  0.172599 -0.046410  0.188544 -0.576345    62   252
# 2  0.040699 -0.089845 -0.026933 -0.048527 -0.012133 -0.576734    62   252
# 3  0.049729 -0.060624 -0.063212 -0.047016 -0.098563 -0.576737    62   252
# 4 -0.140417 -0.075235 -0.117630 -0.047554 -0.102057 -0.576617   254   252
#
#       sload     dload  ...  ct_dst_src_ltm  is_ftp_login  ct_ftp_cmd  \
# 0 -0.389897 -0.273700  ...       -0.705529             0           0
# 1 -0.389928 -0.069233  ...       -0.614256             0           0
# 2 -0.389964 -0.252044  ...       -0.522983             0           0
# 3 -0.389958 -0.275821  ...       -0.522983             1           1
# 4 -0.389927 -0.275561  ...        2.854115             0           0
#
#    ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  label  \
# 0                 0   -0.715714   -0.753074                0      0
# 1                 0   -0.715714   -0.288257                0      0
# 2                 0   -0.595543   -0.288257                0      0
# 3                 0   -0.595543   -0.753074                0      0
# 4                 0   -0.595543    2.779535                0      0
#
#    attack_cat_encode  attack_cat
# 0                  6      Normal
# 1                  6      Normal
# 2                  6      Normal
# 3                  6      Normal
# 4                  6      Normal
#
# [5 rows x 42 columns]

# %%
# save dataset (use df_clean which has standardized numeric columns)
df_clean.to_csv("data/unbalanced_data_standardized.csv", index=False)

# %%
# Print categorical and numeric column information based on unique value threshold
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()

# Filter columns with more than 40 unique values (continuous/numeric)
continuous_cols = [col for col in numeric_cols if df[col].nunique() > 40]
# Filter columns with ≤40 unique values (categorical)
cat_cols = [col for col in numeric_cols if df[col].nunique() <= 40]

# Get indices of categorical columns
cat_indices = [df.columns.get_loc(col) for col in cat_cols]
print("Categorical column indices:", ",".join(map(str, cat_indices)))

# Print continuous/numeric columns
print("Continuous/Numeric columns:", continuous_cols)
# Out:
# Categorical column indices: 6,7,16,19,25,28,31,33,34,35,38,39,40
# Continuous/Numeric columns: ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'sload', 'dload', 'sloss', 'dloss', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'stcpb', 'dtcpb', 'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'response_body_len', 'ct_srv_src', 'ct_dst_ltm', 'ct_src_dport_ltm', 'ct_dst_src_ltm', 'ct_src_ltm', 'ct_srv_dst']

# %%
# Get the first 40 numeric columns for PCA
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
features_for_pca = numeric_cols[:39]
print(f"Using {len(features_for_pca)} features for PCA")

# Extract features and normalize
X = df[features_for_pca].values
scaler = StandardScaler()
X_normalized = scaler.fit_transform(X)
print("Data normalized with StandardScaler")

# Perform PCA
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_normalized)

# Create dataframe with PCA results
pca_df = pd.DataFrame({
    'PC1': X_pca[:, 0],
    'PC2': X_pca[:, 1],
    'PC3': X_pca[:, 2],
    'attack_cat': df['attack_cat'].values
})

print(f"Explained variance ratio: PC1={pca.explained_variance_ratio_[0]:.4f}, PC2={pca.explained_variance_ratio_[1]:.4f}, PC3={pca.explained_variance_ratio_[2]:.4f}")
print(f"Total explained variance: {sum(pca.explained_variance_ratio_):.4f}")
# Out:
# Using 39 features for PCA
# Data normalized with StandardScaler
# Explained variance ratio: PC1=0.2545, PC2=0.0984, PC3=0.0914
# Total explained variance: 0.4442

# %% [markdown]
# ## PCA results (graph)

# %%
# Plot PCA results: PC1 vs PC2 colored by attack category
fig, ax = plt.subplots(figsize=(12, 8))

# Get unique classes and assign colors
classes = pca_df['attack_cat'].unique()
colors = plt.cm.tab10(np.linspace(0, 1, len(classes)))

for i, cls in enumerate(classes):
    mask = pca_df['attack_cat'] == cls
    ax.scatter(pca_df.loc[mask, 'PC1'], pca_df.loc[mask, 'PC2'], 
               c=[colors[i]], label=cls, alpha=0.6, s=10)

ax.set_xlabel(f'PC1 (Eigenvalue 1) - {pca.explained_variance_ratio_[0]*100:.2f}% variance')
ax.set_ylabel(f'PC2 (Eigenvalue 2) - {pca.explained_variance_ratio_[1]*100:.2f}% variance')
ax.set_title('PCA of First 40 Features by Attack Category')
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
fig.savefig(f"./pca/PC1_PC2_plot.png", dpi=150)
plt.show()

# Plot PCA results: PC1 vs PC3 colored by attack category
fig, ax = plt.subplots(figsize=(12, 8))
 
# Get unique classes and assign colors
classes = pca_df['attack_cat'].unique()
colors = plt.cm.tab10(np.linspace(0, 1, len(classes)))

for i, cls in enumerate(classes):
    mask = pca_df['attack_cat'] == cls
    ax.scatter(pca_df.loc[mask, 'PC1'], pca_df.loc[mask, 'PC3'], 
               c=[colors[i]], label=cls, alpha=0.6, s=10)

ax.set_xlabel(f'PC1 (Eigenvalue 1) - {pca.explained_variance_ratio_[0]*100:.2f}% variance')
ax.set_ylabel(f'PC3 (Eigenvalue 3) - {pca.explained_variance_ratio_[2]*100:.2f}% variance')
ax.set_title('PCA of First 40 Features by Attack Category')
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
fig.savefig(f"./pca/PC1_PC3_plot.png", dpi=150)
plt.show()

# Plot PCA results: PC2 vs PC3 colored by attack category
fig, ax = plt.subplots(figsize=(12, 8))

# Get unique classes and assign colors
classes = pca_df['attack_cat'].unique()
colors = plt.cm.tab10(np.linspace(0, 1, len(classes)))

for i, cls in enumerate(classes):
    mask = pca_df['attack_cat'] == cls
    ax.scatter(pca_df.loc[mask, 'PC2'], pca_df.loc[mask, 'PC3'], 
               c=[colors[i]], label=cls, alpha=0.6, s=10)

ax.set_xlabel(f'PC2 (Eigenvalue 2) - {pca.explained_variance_ratio_[1]*100:.2f}% variance')
ax.set_ylabel(f'PC3 (Eigenvalue 3) - {pca.explained_variance_ratio_[2]*100:.2f}% variance')
ax.set_title('PCA of First 40 Features by Attack Category')
ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
fig.savefig(f"./pca/PC2_PC3_plot.png", dpi=150)
plt.show()

# %% [markdown]
# ## 3D PCA results

# %%
# Plot PCA results 
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Get unique classes and assign colors
classes = pca_df['attack_cat'].unique()
colors = plt.cm.tab10(np.linspace(0, 1, len(classes)))

for i, cls in enumerate(classes):
    mask = pca_df['attack_cat'] == cls
    ax.scatter(pca_df.loc[mask, 'PC1'], pca_df.loc[mask, 'PC2'], pca_df.loc[mask, 'PC3'], 
               c=[colors[i]], label=cls, alpha=0.5, s=1)

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('PCs 1-3 of first 40 features by attack category')

legend_handles = []
for i, cls in enumerate(classes):
    handle = ax.scatter([], [], [], 
                        c=[colors[i]], 
                        label=cls,
                        alpha=1.0, 
                        s=10)  
    legend_handles.append(handle)

fig.savefig(f"./pca/3d_pca_plot.png", dpi=150)

ax.legend(handles=legend_handles, bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Plot PCA results 
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Get unique classes and assign colors
classes = pca_df['attack_cat'].unique()
colors = plt.cm.tab10(np.linspace(0, 1, len(classes)))

for i, cls in enumerate(classes):
    mask = pca_df['attack_cat'] == cls
    ax.scatter(pca_df.loc[mask, 'PC1'], pca_df.loc[mask, 'PC2'], pca_df.loc[mask, 'PC3'], 
               c=[colors[i]], label=cls, alpha=0.5, s=1)

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('PCs 1-3 of first 40 features by attack category')
ax.view_init(elev=30, azim=45) 

legend_handles = []
for i, cls in enumerate(classes):
    handle = ax.scatter([], [], [], 
                        c=[colors[i]], 
                        label=cls,
                        alpha=1.0, 
                        s=10)  
    legend_handles.append(handle)

ax.legend(handles=legend_handles, bbox_to_anchor=(1.05, 1), loc='upper left')
fig.savefig(f"./pca/3d_pca_plot_30_45.png", dpi=150)

plt.tight_layout()
plt.show()

# %%
# Plot PCA results 
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Get unique classes and assign colors
classes = pca_df['attack_cat'].unique()
colors = plt.cm.tab10(np.linspace(0, 1, len(classes)))

for i, cls in enumerate(classes):
    mask = pca_df['attack_cat'] == cls
    ax.scatter(pca_df.loc[mask, 'PC1'], pca_df.loc[mask, 'PC2'], pca_df.loc[mask, 'PC3'], 
               c=[colors[i]], label=cls, alpha=0.5, s=1)

ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('PCs 1-3 of first 40 features by attack category')
ax.view_init(elev=30, azim=90) 

legend_handles = []
for i, cls in enumerate(classes):
    handle = ax.scatter([], [], [], 
                        c=[colors[i]], 
                        label=cls,
                        alpha=1.0, 
                        s=10)  
    legend_handles.append(handle)

ax.legend(handles=legend_handles, bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

fig.savefig(f"./pca/3d_pca_plot_30_90.png", dpi=150)

# %%
# save df
pca_df.to_csv("./data/pca_unbalanced_data.csv", index=False)
